# %%
import sys
sys.path.append("..")
import os
cwd = os.getcwd()
from src.data import MNISTDataset
from src.data import getDataset, getDataloader
from src.metrics import mse
from src.forward.metrics import ELBO, get_beta
from src.forward.uncertainty_estimation import get_uncertainty_per_batch
from src.forward.inference_func import run

# %%
import os
os.chdir('/Users/4romain/pCloud Drive/ml_master_thesis/repo/')
cwd = os.getcwd()
print(cwd)
main_data = MNISTDataset('train', 'thickness', data_type='processed/original_thic_resample')
scaler = main_data.scaler
# Out:
# /Users/4romain/pCloud Drive/ml_master_thesis/repo
#  ---------------------------------------- CHECK NANS
# Empty DataFrame
# Columns: [index, area, length, thickness, slant, width, height, digit]
# Index: []
#                index          area        length     thickness         slant  \
# count   28960.000000  28960.000000  28960.000000  28960.000000  28960.000000
# mean   133952.423135    125.837118     40.835467      3.311931      0.093532
# std     92641.010286     64.984782     10.869578      1.485387      0.252856
# min        18.000000     10.812500      9.035534      0.810550     -0.923000
# 25%     48954.000000     68.875000     34.281223      1.942716     -0.080793
# 50%    126484.500000    117.875000     41.045310      3.273769      0.088171
# 75%    204788.250000    174.000000     48.412951      4.601186      0.268696
# max    359977.000000    340.500000     80.815494      5.999780      1.064476
#
#               width        height         digit
# ...

# %%
# With bbb, relu, and lr = 0.001
net_type = 'lenet'
dataset_name = 'transformed_morpho_MNIST_resample'
run(dataset_name, net_type)
# Out:
#  ---------------------------------------- CHECK NANS
# Empty DataFrame
# Columns: [index, area, length, thickness, slant, width, height, digit]
# Index: []
#                index          area        length     thickness         slant  \
# count   28960.000000  28960.000000  28960.000000  28960.000000  28960.000000
# mean   133952.423135    125.837118     40.835467      3.311931      0.093532
# std     92641.010286     64.984782     10.869578      1.485387      0.252856
# min        18.000000     10.812500      9.035534      0.810550     -0.923000
# 25%     48954.000000     68.875000     34.281223      1.942716     -0.080793
# 50%    126484.500000    117.875000     41.045310      3.273769      0.088171
# 75%    204788.250000    174.000000     48.412951      4.601186      0.268696
# max    359977.000000    340.500000     80.815494      5.999780      1.064476
#
#               width        height         digit
# count  28960.000000  28960.000000  28960.000000
# ...
